# %%
from datetime import datetime
from datetime import timedelta

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import os
import json
from tqdm.notebook import tqdm
import plotly.express as px
import plotly

# %%
with open('config/config.json', 'r') as file:
    config = json.load(file)
    
with open('config/config_emb_path.json', 'r') as file:
    config_emb = json.load(file)
    
rs = config['random_state']

year_start = 2021

for key in config_emb.keys():
    config_emb[key] = config_emb[key].format(year_start)

# %%
config['financial_metric_path'].format(year_start)
# Out:
# 'results/financial_metric_2021.csv'

# %%
financial_metrics = {year_start:pd.read_csv(config['financial_metric_path'].format(year_start), index_col=0) 
                     for year_start in [2020, 2021]}

# %%
financial_metrics[2020].sort_values('Sharpe', ascending=False)
# Out:
#                                AVG_returns      Risk      Beta     Alpha  \
# takens_mult_PI_2_sigma=0.0005     0.001869  0.018564  0.701615  0.001648
# takens_one_PL_2                   0.001624  0.015988  0.717754  0.001401
# fastica                           0.002111  0.021907  0.597069  0.001906
# pca                               0.002111  0.021907  0.597069  0.001906
# takens_mult_BC_0                  0.001820  0.019969  0.664694  0.001605
# takens_one_PL_1                   0.001614  0.020581  0.647850  0.001401
# transformer_embds3                0.001515  0.019882  0.692306  0.001296
# takens_one_BC_2                   0.001429  0.018749  0.724370  0.001205
# takens_mult_PL_1                  0.001709  0.022848  0.605423  0.001503
# transformer_embds_sum_23          0.001513  0.020952  0.656167  0.001299
# transformer_embds1                0.001402  0.020005  0.680248  0.001184
# umap                              0.001272  0.018719  0.688975  0.001053
# ...

# %%
financial_metrics[2021].sort_values('Sharpe', ascending=False)
# Out:
#                                AVG_returns      Risk      Beta     Alpha  \
# table_finance_features            0.002044  0.015220  0.501459  0.002071
# takens_one_PI_1_sigma=0.0005      0.001124  0.011903  0.667905  0.001199
# autoencoder_conv                  0.001937  0.022842  0.367119  0.001926
# umap                              0.001279  0.016406  0.490367  0.001303
# tsfresh                           0.001278  0.017993  0.460348  0.001294
# takens_one_BC_0                   0.001311  0.019046  0.434700  0.001319
# takens_mult_BC_0                  0.000970  0.013891  0.662852  0.001044
# takens_mult_PI_2_sigma=0.0005     0.000803  0.011289  0.736860  0.000898
# sectors                           0.001205  0.018072  0.421275  0.001209
# tnse                              0.000958  0.014182  0.604034  0.001015
# takens_mult_PI_1_sigma=0.0005     0.000817  0.012622  0.639943  0.000884
# takens_mult_PL_1                  0.001015  0.018024  0.496577  0.001041
# ...
