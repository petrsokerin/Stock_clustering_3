# %%
from datetime import datetime
from datetime import timedelta

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import os
import json
from tqdm.notebook import tqdm
import plotly.express as px
import plotly

from comet_ml import Experiment

# %%
with open('config/config.json', 'r') as file:
    config = json.load(file)
    
with open('config/config_emb_path.json', 'r') as file:
    config_emb = json.load(file)
    
rs = config['random_state']

# %%
def change_features(df):
    df['AVG_returns'] = (df['AVG_returns'] + 1) ** 252 - 1
    df['Risk'] = (df['Risk'] + 1) ** np.sqrt(252) - 1
    df['Alpha'] = df['Alpha'].round(4)
    df['Drawdown'] = -df['Drawdown']
    

    return df

# %% [markdown]
# # Visualization

# %%
config['financial_metric_path'].format(year_start, fine_tune)
# Out:
# 'results/financial_metric_2021_False.csv'

# %%
financial_metrics = {year_start:pd.read_csv(config['financial_metric_path'].format(year_start, fine_tune), index_col=0) 
                     for year_start in [2020, 2021]}

# %%
df_2020 = change_features(financial_metrics[2020])
df_2021 = change_features(financial_metrics[2021])

# %%
def filter_risk_return(df, filter_baselines=['sp500', 'sectors'], save_methods=['sectors', 'sp500']):      
        
    for baseline in filter_baselines:

        risk_baseline = df[df.emb_model == baseline]['Risk'].values[0]
        mask_risk = df['Risk'] <= risk_baseline
        mask = mask_risk

        return_baseline = df[df.emb_model == baseline]['AVG_returns'].values[0]
        mask_return = df['AVG_returns'] >= return_baseline
        mask = mask & mask_return
        
        drd_baseline = df[df.emb_model == baseline]['Drawdown'].values[0]
        mask_drd = df['Drawdown'] <= drd_baseline
        mask = mask & mask_drd
        
        mask_save = df['emb_model'].isin(save_methods)
        mask = mask | mask_save

        df = df[mask]
        
    mask_save = df['emb_model'].isin(save_methods)
    df = df[(df['AVG_returns'] > 0) | mask_save]
    return df.sort_values('Sharpe', ascending=False)

# %%
df_2021_filtered = filter_risk_return(df_2021, filter_baselines=['sectors'], 
                                      save_methods=['sectors', 'sp500'])
df_2021_filtered
# Out:
#       AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# port     0.672739  0.270982  0.501459  0.0021  0.126564 -0.025113  12.020327
# port     0.414883  0.208473  0.605803  0.0014  0.105069 -0.019800  11.293906
# port     0.491682  0.315458  0.468096  0.0016  0.084426 -0.028746  16.850101
# port     0.354555  0.328862  0.421275  0.0012  0.060186 -0.029819  20.176808
# port    -0.042238  0.203246  1.000000  0.0000 -0.024612 -0.019344  25.081503
#
#       Recovery clust_model               emb_model
# port      65.0      KMeans  table_finance_features
# port      78.0         Agg  table_finance_features
# port      73.0         Agg                 tsfresh
# port      88.0     sectors                 sectors
# port     179.0       sp500                   sp500

# %%
df_2020_filtered = filter_risk_return(df_2020, filter_baselines=['sectors'], 
                                      save_methods=['sectors', 'sp500'])
df_2020_filtered
# Out:
#       AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# port     0.600734  0.339103  0.701615  0.0016  0.094339 -0.030631  33.631090
# port     0.505332  0.286336  0.717754  0.0014  0.094262 -0.026381  14.655753
# port     0.521516  0.329129  0.709373  0.0014  0.085684 -0.029840  21.298497
# port     0.581317  0.368728  0.664694  0.0016  0.085272 -0.032950  28.935546
# port     0.449200  0.304558  0.787807  0.0012  0.080292 -0.027867  31.327309
# port     0.454484  0.324734  0.742873  0.0013  0.076683 -0.029490  29.773179
# port     0.501222  0.381811  0.647850  0.0014  0.072699 -0.033958  31.645513
# port     0.389792  0.296542  0.794970  0.0011  0.072130 -0.027215  37.944779
# port     0.464639  0.366876  0.692306  0.0013  0.070321 -0.032806  32.784684
# port     0.433002  0.342955  0.724370  0.0012  0.069945 -0.030936  26.039232
# port     0.458292  0.373351  0.690987  0.0013  0.068409 -0.033307  32.183046
# port     0.428275  0.352416  0.712236  0.0012  0.067619 -0.031679  35.920772
# port     0.464833  0.385091  0.651090  0.0013  0.067461 -0.034210  30.864434
# port     0.423275  0.369481  0.680248  0.0012  0.064200 -0.033008  32.500412
# port     0.380717  0.335222  0.696776  0.0011  0.063318 -0.030324  31.249841
# port     0.410354  0.370762  0.673659  0.0011  0.062202 -0.033107  38.041480
# port     0.407141  0.368544  0.685490  0.0011  0.062072 -0.032935  30.835164
# port     0.377516  0.342339  0.688975  0.0011  0.061672 -0.030887  40.743809
# port     0.373594  0.341360  0.705352  0.0010  0.061220 -0.030810  36.369420
# port     0.387615  0.358618  0.683558  0.0011  0.060713 -0.032164  30.531414
# port     0.394366  0.367924  0.688580  0.0011  0.060345 -0.032887  30.988097
# port     0.373479  0.348221  0.735523  0.0010  0.060147 -0.031350  29.728959
# port     0.367042  0.342642  0.735933  0.0010  0.060006 -0.030911  32.693414
# port     0.400226  0.376660  0.663268  0.0011  0.059950 -0.033562  36.970291
# port     0.391985  0.375150  0.651824  0.0011  0.059002 -0.033446  41.586482
# port     0.380779  0.371540  0.687717  0.0011  0.057900 -0.033167  40.151673
# port     0.358118  0.374996  0.673019  0.0010  0.054193 -0.033434  38.396694
# port     0.345204  0.385629  0.605734  0.0010  0.051072 -0.034251  42.313929
# port     0.068939  0.288985  1.000000  0.0000  0.009137 -0.026598  33.924960
#
#       Recovery clust_model                      emb_model
# port      57.0      KMeans  takens_mult_PI_2_sigma=0.0005
# port      83.0      KMeans                takens_one_PL_2
# port     115.0         Agg                takens_one_PL_2
# port      50.0      KMeans               takens_mult_BC_0
# port     180.0         Agg  takens_mult_PI_2_sigma=0.0005
# port     115.0         Agg                takens_one_BC_2
# port     182.0      KMeans                takens_one_PL_1
# port      69.0         Agg   takens_one_PI_1_sigma=0.0005
# port      89.0      KMeans             transformer_embds3
# port      83.0      KMeans                takens_one_BC_2
# port      90.0         Agg                takens_one_PL_1
# port     137.0         Agg                takens_one_BC_1
# port     122.0         Agg       transformer_embds_sum_23
# port     119.0      KMeans             transformer_embds1
# port      75.0         Agg             transformer_embds2
# port     100.0         Agg                         ts2vec
# port     119.0         Agg             transformer_embds1
# port     190.0      KMeans                           umap
# port      91.0      KMeans         table_finance_features
# port     182.0      KMeans             transformer_embds2
# port     122.0         Agg             transformer_embds3
# port     147.0      KMeans                takens_one_BC_1
# port     119.0      KMeans               takens_mult_PL_2
# port     122.0     MSTcorr                        MSTcorr
# port      89.0      KMeans                        tsfresh
# port     122.0         Agg               autoencoder_lstm
# port     122.0      KMeans               autoencoder_lstm
# port     185.0     sectors                        sectors
# port     179.0       sp500                          sp500

# %%
df_2020_filtered[df_2020_filtered.clust_model != 'Agg']
# Out:
#       AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# port     0.600734  0.339103  0.701615  0.0016  0.094339 -0.030631  33.631090
# port     0.505332  0.286336  0.717754  0.0014  0.094262 -0.026381  14.655753
# port     0.581317  0.368728  0.664694  0.0016  0.085272 -0.032950  28.935546
# port     0.501222  0.381811  0.647850  0.0014  0.072699 -0.033958  31.645513
# port     0.464639  0.366876  0.692306  0.0013  0.070321 -0.032806  32.784684
# port     0.433002  0.342955  0.724370  0.0012  0.069945 -0.030936  26.039232
# port     0.423275  0.369481  0.680248  0.0012  0.064200 -0.033008  32.500412
# port     0.377516  0.342339  0.688975  0.0011  0.061672 -0.030887  40.743809
# port     0.373594  0.341360  0.705352  0.0010  0.061220 -0.030810  36.369420
# port     0.387615  0.358618  0.683558  0.0011  0.060713 -0.032164  30.531414
# port     0.373479  0.348221  0.735523  0.0010  0.060147 -0.031350  29.728959
# port     0.367042  0.342642  0.735933  0.0010  0.060006 -0.030911  32.693414
# port     0.400226  0.376660  0.663268  0.0011  0.059950 -0.033562  36.970291
# port     0.391985  0.375150  0.651824  0.0011  0.059002 -0.033446  41.586482
# port     0.358118  0.374996  0.673019  0.0010  0.054193 -0.033434  38.396694
# port     0.345204  0.385629  0.605734  0.0010  0.051072 -0.034251  42.313929
# port     0.068939  0.288985  1.000000  0.0000  0.009137 -0.026598  33.924960
#
#       Recovery clust_model                      emb_model
# port      57.0      KMeans  takens_mult_PI_2_sigma=0.0005
# port      83.0      KMeans                takens_one_PL_2
# port      50.0      KMeans               takens_mult_BC_0
# port     182.0      KMeans                takens_one_PL_1
# port      89.0      KMeans             transformer_embds3
# port      83.0      KMeans                takens_one_BC_2
# port     119.0      KMeans             transformer_embds1
# port     190.0      KMeans                           umap
# port      91.0      KMeans         table_finance_features
# port     182.0      KMeans             transformer_embds2
# port     147.0      KMeans                takens_one_BC_1
# port     119.0      KMeans               takens_mult_PL_2
# port     122.0     MSTcorr                        MSTcorr
# port      89.0      KMeans                        tsfresh
# port     122.0      KMeans               autoencoder_lstm
# port     185.0     sectors                        sectors
# port     179.0       sp500                          sp500

# %%
df_2020_filtered[df_2020_filtered.clust_model != 'KMeans']
# Out:
#       AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# port     0.521516  0.329129  0.709373  0.0014  0.085684 -0.029840  21.298497
# port     0.449200  0.304558  0.787807  0.0012  0.080292 -0.027867  31.327309
# port     0.454484  0.324734  0.742873  0.0013  0.076683 -0.029490  29.773179
# port     0.389792  0.296542  0.794970  0.0011  0.072130 -0.027215  37.944779
# port     0.458292  0.373351  0.690987  0.0013  0.068409 -0.033307  32.183046
# port     0.428275  0.352416  0.712236  0.0012  0.067619 -0.031679  35.920772
# port     0.464833  0.385091  0.651090  0.0013  0.067461 -0.034210  30.864434
# port     0.380717  0.335222  0.696776  0.0011  0.063318 -0.030324  31.249841
# port     0.410354  0.370762  0.673659  0.0011  0.062202 -0.033107  38.041480
# port     0.407141  0.368544  0.685490  0.0011  0.062072 -0.032935  30.835164
# port     0.394366  0.367924  0.688580  0.0011  0.060345 -0.032887  30.988097
# port     0.400226  0.376660  0.663268  0.0011  0.059950 -0.033562  36.970291
# port     0.380779  0.371540  0.687717  0.0011  0.057900 -0.033167  40.151673
# port     0.345204  0.385629  0.605734  0.0010  0.051072 -0.034251  42.313929
# port     0.068939  0.288985  1.000000  0.0000  0.009137 -0.026598  33.924960
#
#       Recovery clust_model                      emb_model
# port     115.0         Agg                takens_one_PL_2
# port     180.0         Agg  takens_mult_PI_2_sigma=0.0005
# port     115.0         Agg                takens_one_BC_2
# port      69.0         Agg   takens_one_PI_1_sigma=0.0005
# port      90.0         Agg                takens_one_PL_1
# port     137.0         Agg                takens_one_BC_1
# port     122.0         Agg       transformer_embds_sum_23
# port      75.0         Agg             transformer_embds2
# port     100.0         Agg                         ts2vec
# port     119.0         Agg             transformer_embds1
# port     122.0         Agg             transformer_embds3
# port     122.0     MSTcorr                        MSTcorr
# port     122.0         Agg               autoencoder_lstm
# port     185.0     sectors                        sectors
# port     179.0       sp500                          sp500

# %% [markdown]
# ## COMET_ML

# %%
year_start = 2020
fine_tune = True

for key in config_emb.keys():
    config_emb[key] = config_emb[key].format(year_start)

# %%
df_finance = pd.read_csv(config['financial_metric_path'].format(year_start, fine_tune), index_col=0)
df_clust = pd.read_csv(config['clust_metric_path'].format(year_start, fine_tune), index_col=0)

df_finance = change_features(df_finance)

# %%
df_finance.head()
# Out:
#       AVG_returns      Risk      Beta   Alpha    Sharpe       VaR   Drawdown  \
# port     0.495915  0.411040  0.601512  0.0014  0.067593 -0.036180  43.955665
# port     0.191167  0.363129  0.640662  0.0005  0.029286 -0.032515  36.463147
# port     0.404731  0.356168  0.696695  0.0011  0.063590 -0.031973  35.514546
# port    -0.065147  0.247098  0.941967 -0.0005 -0.027456 -0.023112  31.130780
# port     0.606091  0.355021  0.674516  0.0017  0.091323 -0.031883  24.775282
#
#       Recovery clust_model        emb_model
# port      75.0      KMeans           ts2vec
# port     154.0         Agg           ts2vec
# port     115.0      KMeans  takens_one_BC_2
# port     642.0         Agg  takens_one_BC_2
# port      57.0      KMeans  takens_one_PL_2

# %%
model_del = 'Agg' if model_name == 'KMeans' else 'KMeans'

df_finance = df_finance[df_finance.clust_model != model_del]
df_clust = df_clust[df_clust.clust_model != model_del]

df_finance = df_finance.set_index('emb_model').drop(columns=['clust_model'])
df_clust = df_clust.set_index('emb_model').drop(columns=['clust_model'])

df_data = df_finance.join(df_clust)

assert len(df_data) == len(df_clust) + 1 == len(df_finance)
df_data.head()
# Out:
#                           AVG_returns      Risk      Beta   Alpha    Sharpe  \
# emb_model
# ts2vec                       0.191167  0.363129  0.640662  0.0005  0.029286
# takens_one_BC_2             -0.065147  0.247098  0.941967 -0.0005 -0.027456
# takens_one_PL_2              0.156138  0.317826  0.740148  0.0003  0.026150
# transformer_embds_sum_23     0.330917  0.359422  0.667278  0.0009  0.052108
# transformer_embds3           0.350557  0.343130  0.696339  0.0010  0.057361
#
#                                VaR   Drawdown  Recovery        DB          HC  \
# emb_model
# ts2vec                   -0.032515  36.463147     154.0  0.320173   18.543424
# takens_one_BC_2          -0.023112  31.130780     642.0  0.453790    6.411142
# takens_one_PL_2          -0.028937  28.214303     182.0  0.311802   10.268861
# transformer_embds_sum_23 -0.032227  36.297709     180.0  1.142738  130.819923
# transformer_embds3       -0.030949  34.166709     180.0  1.202075  129.118784
#
#                                Sil       hom
# emb_model
# ts2vec                    0.516730  0.028243
# takens_one_BC_2           0.273747  0.028900
# takens_one_PL_2           0.379736  0.023011
# transformer_embds_sum_23  0.216855  0.051649
# transformer_embds3        0.223701  0.054524

# %%
for model_name, data in tqdm(df_model.iterrows()):
    
    experiment = Experiment(
    api_key="W4Exl5JlKMoVHRelfS04Tc0Lg",
    project_name="stock-clustering-with-time-series-embeddings",
    workspace="petrsokerin",
    )

    experiment.set_name(model_name)

    hyper_params = {
        "model": model_name,
        "include_2020": year_start == 2021,
        "fine_tune": fine_tune,
    }

    experiment.log_parameters(hyper_params)
    
    print(model_name)
    metrics = data.to_dict()
    experiment.log_metrics(metrics)
# Out:
# 0it [00:00, ?it/s]
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET ERROR: Run will not be logged
# For more details, please refer to: https://www.comet.com/docs/python-sdk/warnings-errors/
# Traceback (most recent call last):
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/experiment.py", line 946, in _start
#     self.alive = self._setup_streamer()
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 328, in _setup_streamer
#     self._initialize_streamer(
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 433, in _initialize_streamer
#     self.ws_connection.start()
#   File "/opt/anaconda3/envs/cuda10/lib/python3.8/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# ts2vec
# COMET ERROR: Run will not be logged
# For more details, please refer to: https://www.comet.com/docs/python-sdk/warnings-errors/
# Traceback (most recent call last):
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/experiment.py", line 946, in _start
#     self.alive = self._setup_streamer()
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 328, in _setup_streamer
#     self._initialize_streamer(
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 433, in _initialize_streamer
#     self.ws_connection.start()
#   File "/opt/anaconda3/envs/cuda10/lib/python3.8/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# takens_one_BC_2
# COMET ERROR: Run will not be logged
# For more details, please refer to: https://www.comet.com/docs/python-sdk/warnings-errors/
# Traceback (most recent call last):
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/experiment.py", line 946, in _start
#     self.alive = self._setup_streamer()
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 328, in _setup_streamer
#     self._initialize_streamer(
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 433, in _initialize_streamer
#     self.ws_connection.start()
#   File "/opt/anaconda3/envs/cuda10/lib/python3.8/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# takens_one_PL_2
# COMET ERROR: Run will not be logged
# For more details, please refer to: https://www.comet.com/docs/python-sdk/warnings-errors/
# Traceback (most recent call last):
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/experiment.py", line 946, in _start
#     self.alive = self._setup_streamer()
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 328, in _setup_streamer
#     self._initialize_streamer(
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 433, in _initialize_streamer
#     self.ws_connection.start()
#   File "/opt/anaconda3/envs/cuda10/lib/python3.8/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# transformer_embds_sum_23
# COMET ERROR: Run will not be logged
# For more details, please refer to: https://www.comet.com/docs/python-sdk/warnings-errors/
# Traceback (most recent call last):
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/experiment.py", line 946, in _start
#     self.alive = self._setup_streamer()
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 328, in _setup_streamer
#     self._initialize_streamer(
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 433, in _initialize_streamer
#     self.ws_connection.start()
#   File "/opt/anaconda3/envs/cuda10/lib/python3.8/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# transformer_embds3
# COMET ERROR: Run will not be logged
# For more details, please refer to: https://www.comet.com/docs/python-sdk/warnings-errors/
# Traceback (most recent call last):
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/experiment.py", line 946, in _start
#     self.alive = self._setup_streamer()
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 328, in _setup_streamer
#     self._initialize_streamer(
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 433, in _initialize_streamer
#     self.ws_connection.start()
#   File "/opt/anaconda3/envs/cuda10/lib/python3.8/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# transformer_embds2
# COMET ERROR: Run will not be logged
# For more details, please refer to: https://www.comet.com/docs/python-sdk/warnings-errors/
# Traceback (most recent call last):
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/experiment.py", line 946, in _start
#     self.alive = self._setup_streamer()
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 328, in _setup_streamer
#     self._initialize_streamer(
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 433, in _initialize_streamer
#     self.ws_connection.start()
#   File "/opt/anaconda3/envs/cuda10/lib/python3.8/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# takens_mult_PI_0_sigma=0.0005
# COMET ERROR: Run will not be logged
# For more details, please refer to: https://www.comet.com/docs/python-sdk/warnings-errors/
# Traceback (most recent call last):
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/experiment.py", line 946, in _start
#     self.alive = self._setup_streamer()
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 328, in _setup_streamer
#     self._initialize_streamer(
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 433, in _initialize_streamer
#     self.ws_connection.start()
#   File "/opt/anaconda3/envs/cuda10/lib/python3.8/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# takens_mult_PL_2
# COMET ERROR: Run will not be logged
# For more details, please refer to: https://www.comet.com/docs/python-sdk/warnings-errors/
# Traceback (most recent call last):
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/experiment.py", line 946, in _start
#     self.alive = self._setup_streamer()
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 328, in _setup_streamer
#     self._initialize_streamer(
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 433, in _initialize_streamer
#     self.ws_connection.start()
#   File "/opt/anaconda3/envs/cuda10/lib/python3.8/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# takens_one_BC_1
# COMET ERROR: Run will not be logged
# For more details, please refer to: https://www.comet.com/docs/python-sdk/warnings-errors/
# Traceback (most recent call last):
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/experiment.py", line 946, in _start
#     self.alive = self._setup_streamer()
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 328, in _setup_streamer
#     self._initialize_streamer(
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 433, in _initialize_streamer
#     self.ws_connection.start()
#   File "/opt/anaconda3/envs/cuda10/lib/python3.8/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# table_finance_features
# COMET ERROR: Run will not be logged
# For more details, please refer to: https://www.comet.com/docs/python-sdk/warnings-errors/
# Traceback (most recent call last):
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/experiment.py", line 946, in _start
#     self.alive = self._setup_streamer()
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 328, in _setup_streamer
#     self._initialize_streamer(
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 433, in _initialize_streamer
#     self.ws_connection.start()
#   File "/opt/anaconda3/envs/cuda10/lib/python3.8/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# takens_mult_PI_1_sigma=0.0005
# COMET ERROR: Run will not be logged
# For more details, please refer to: https://www.comet.com/docs/python-sdk/warnings-errors/
# Traceback (most recent call last):
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/experiment.py", line 946, in _start
#     self.alive = self._setup_streamer()
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 328, in _setup_streamer
#     self._initialize_streamer(
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 433, in _initialize_streamer
#     self.ws_connection.start()
#   File "/opt/anaconda3/envs/cuda10/lib/python3.8/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# signal2vec_embds
# COMET ERROR: Run will not be logged
# For more details, please refer to: https://www.comet.com/docs/python-sdk/warnings-errors/
# Traceback (most recent call last):
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/experiment.py", line 946, in _start
#     self.alive = self._setup_streamer()
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 328, in _setup_streamer
#     self._initialize_streamer(
#   File "/cephfs/projects/psoker/.local/lib/python3.8/site-packages/comet_ml/_online.py", line 433, in _initialize_streamer
#     self.ws_connection.start()
#   File "/opt/anaconda3/envs/cuda10/lib/python3.8/threading.py", line 852, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# autoencoder_mlp
